# %%
# !wget -q https://git.io/J0fjL -O IAM_Words.zip

# !unzip -qq IAM_Words.zip
# !mkdir Outputs2
# !mkdir InputImages
# !mkdir data
# !mkdir data/words
# !tar -xf IAM_Words/words.tgz -C data/words
# !mv IAM_Words/words.txt data
# Out:
# replace IAM_Words/words.tgz? [y]es, [n]o, [A]ll, [N]one, [r]ename: mkdir: cannot create directory ‘Outputs2’: File exists
# mkdir: cannot create directory ‘InputImages’: File exists
# mkdir: cannot create directory ‘data’: File exists
# mkdir: cannot create directory ‘data/words’: File exists
# ^C
# mv: cannot stat 'IAM_Words/words.txt': No such file or directory

# %%
# !cp /content/drive/MyDrive/Colab Notebooks/OCR-new-new/main.py/content

# %%
# !pip install path
# Out:
# Collecting path
#   Downloading path-17.0.0-py3-none-any.whl.metadata (6.4 kB)
# Downloading path-17.0.0-py3-none-any.whl (24 kB)
# Installing collected packages: path
# Successfully installed path-17.0.0

# %%
image_path="image2.png"
def get_image_height(image_path):
  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image, 1)
  return image.shape[0]

get_image_height(image_path)
xyz=get_image_height(image_path)

# %%
import main
import __init__
import argparse

# Create a dummy argument parser to satisfy the main function's expectations
parser = argparse.ArgumentParser()
args = parser.parse_args([])

# Call the main function with the dummy arguments
main.main()
# Out:
# usage: colab_kernel_launcher.py [-h] [--data DATA] [--kernel_size KERNEL_SIZE] [--sigma SIGMA]
#                                 [--theta THETA] [--min_area MIN_AREA] [--img_height IMG_HEIGHT]
# colab_kernel_launcher.py: error: unrecognized arguments: -f /root/.local/share/jupyter/runtime/kernel-6a533d90-b742-4b16-9702-a6787e695f95.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import main
import __init__
import argparse
# Assuming your main.py script is in the current directory
# %run main.py --data /content/InputImages --kernel_size 25 --sigma 11 --theta 7 --min_area 100 --img_height 1000
# Out:
# Processing file /content/InputImages/english-italic.png
# 92 23 116 33
# ['line0word0.jpg']
# 229 21 113 35
# ['line0word0.jpg', 'line0word1.jpg']
# 359 33 69 22
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg']
# 467 29 16 21
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg']
# 449 21 174 35
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg']
# 641 29 133 35
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg']
# 783 21 45 35
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg']
# 836 24 135 40
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg']
# 979 30 92 26
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg']
# 21 87 49 25
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg']
# 72 79 150 40
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg']
# 91 134 53 34
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg']
# 152 134 126 34
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg']
# 288 134 177 42
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg']
# 474 136 36 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg']
# 518 135 83 33
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg']
# 609 142 92 26
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg']
# 709 136 213 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg']
# 932 134 136 42
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg']
# 22 197 108 25
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg']
# 140 190 122 40
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg']
# 274 190 53 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg']
# 337 193 127 29
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg']
# 495 203 18 13
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg']
# 480 187 99 34
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg']
# 592 190 116 40
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg']
# 719 197 50 25
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg']
# 780 197 195 33
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg']
# 986 197 82 25
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg']
# 22 253 104 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg']
# 131 245 349 33
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg']
# 485 246 67 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg']
# 554 253 185 25
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg']
# 745 246 50 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg']
# 797 251 96 27
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg']
# 899 253 90 33
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg']
# 994 249 74 29
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg']
# 23 300 82 33
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg']
# 106 300 674 42
# /content/main.py:46: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('rainbow', num_colors)
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg']
# 91 356 120 34
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg']
# 220 357 112 39
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg']
# 342 366 32 23
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg']
# 384 358 114 38
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg']
# 509 357 134 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg']
# 655 364 67 25
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg']
# 727 358 46 37
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg']
# 781 358 57 31
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg']
# 845 363 145 34
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg']
# 997 358 77 31
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg']
# 23 417 188 33
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg']
# 222 411 150 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg']
# 394 410 120 34
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg']
# 526 411 112 39
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg']
# 652 412 65 31
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg']
# 730 412 86 31
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg']
# 828 412 57 31
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg']
# 898 411 147 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg']
# 1048 419 23 23
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg']
# 24 467 162 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg']
# 196 467 135 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg']
# 347 474 67 25
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg']
# 423 476 81 22
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg']
# 518 475 90 24
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg']
# 622 467 56 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg']
# 712 479 19 16
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg']
# 696 465 114 34
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg']
# 833 468 96 31
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg']
# 942 476 50 23
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg']
# 1006 476 60 23
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg']
# 22 521 527 41
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg']
# 550 523 521 39
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg']
# 21 589 33 22
# ...
# 431 635 78 31
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg', 'line10word0.jpg', 'line10word1.jpg', 'line10word2.jpg', 'line10word3.jpg', 'line11word0.jpg', 'line11word1.jpg', 'line11word2.jpg', 'line11word3.jpg', 'line11word4.jpg']
# 520 635 68 38
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg', 'line10word0.jpg', 'line10word1.jpg', 'line10word2.jpg', 'line10word3.jpg', 'line11word0.jpg', 'line11word1.jpg', 'line11word2.jpg', 'line11word3.jpg', 'line11word4.jpg', 'line11word5.jpg']
# 595 642 166 25
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg', 'line10word0.jpg', 'line10word1.jpg', 'line10word2.jpg', 'line10word3.jpg', 'line11word0.jpg', 'line11word1.jpg', 'line11word2.jpg', 'line11word3.jpg', 'line11word4.jpg', 'line11word5.jpg', 'line11word6.jpg']
# 775 635 63 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg', 'line10word0.jpg', 'line10word1.jpg', 'line10word2.jpg', 'line10word3.jpg', 'line11word0.jpg', 'line11word1.jpg', 'line11word2.jpg', 'line11word3.jpg', 'line11word4.jpg', 'line11word5.jpg', 'line11word6.jpg', 'line11word7.jpg']
# 836 635 148 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg', 'line10word0.jpg', 'line10word1.jpg', 'line10word2.jpg', 'line10word3.jpg', 'line11word0.jpg', 'line11word1.jpg', 'line11word2.jpg', 'line11word3.jpg', 'line11word4.jpg', 'line11word5.jpg', 'line11word6.jpg', 'line11word7.jpg', 'line11word8.jpg']
# 992 635 81 39
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg', 'line10word0.jpg', 'line10word1.jpg', 'line10word2.jpg', 'line10word3.jpg', 'line11word0.jpg', 'line11word1.jpg', 'line11word2.jpg', 'line11word3.jpg', 'line11word4.jpg', 'line11word5.jpg', 'line11word6.jpg', 'line11word7.jpg', 'line11word8.jpg', 'line11word9.jpg']
# 23 689 247 32
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg', 'line10word0.jpg', 'line10word1.jpg', 'line10word2.jpg', 'line10word3.jpg', 'line11word0.jpg', 'line11word1.jpg', 'line11word2.jpg', 'line11word3.jpg', 'line11word4.jpg', 'line11word5.jpg', 'line11word6.jpg', 'line11word7.jpg', 'line11word8.jpg', 'line11word9.jpg', 'line12word0.jpg']
# 277 694 193 34
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg', 'line10word0.jpg', 'line10word1.jpg', 'line10word2.jpg', 'line10word3.jpg', 'line11word0.jpg', 'line11word1.jpg', 'line11word2.jpg', 'line11word3.jpg', 'line11word4.jpg', 'line11word5.jpg', 'line11word6.jpg', 'line11word7.jpg', 'line11word8.jpg', 'line11word9.jpg', 'line12word0.jpg', 'line12word1.jpg']
# 484 687 370 41
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg', 'line10word0.jpg', 'line10word1.jpg', 'line10word2.jpg', 'line10word3.jpg', 'line11word0.jpg', 'line11word1.jpg', 'line11word2.jpg', 'line11word3.jpg', 'line11word4.jpg', 'line11word5.jpg', 'line11word6.jpg', 'line11word7.jpg', 'line11word8.jpg', 'line11word9.jpg', 'line12word0.jpg', 'line12word1.jpg', 'line12word2.jpg']
# 861 689 202 39
# ['line0word0.jpg', 'line0word1.jpg', 'line0word2.jpg', 'line0word3.jpg', 'line0word4.jpg', 'line0word5.jpg', 'line0word6.jpg', 'line0word7.jpg', 'line0word8.jpg', 'line1word0.jpg', 'line1word1.jpg', 'line2word0.jpg', 'line2word1.jpg', 'line2word2.jpg', 'line2word3.jpg', 'line2word4.jpg', 'line2word5.jpg', 'line2word6.jpg', 'line2word7.jpg', 'line3word0.jpg', 'line3word1.jpg', 'line3word2.jpg', 'line3word3.jpg', 'line3word4.jpg', 'line3word5.jpg', 'line3word6.jpg', 'line3word7.jpg', 'line3word8.jpg', 'line3word9.jpg', 'line4word0.jpg', 'line4word1.jpg', 'line4word2.jpg', 'line4word3.jpg', 'line4word4.jpg', 'line4word5.jpg', 'line4word6.jpg', 'line4word7.jpg', 'line5word0.jpg', 'line5word1.jpg', 'line6word0.jpg', 'line6word1.jpg', 'line6word2.jpg', 'line6word3.jpg', 'line6word4.jpg', 'line6word5.jpg', 'line6word6.jpg', 'line6word7.jpg', 'line6word8.jpg', 'line6word9.jpg', 'line7word0.jpg', 'line7word1.jpg', 'line7word2.jpg', 'line7word3.jpg', 'line7word4.jpg', 'line7word5.jpg', 'line7word6.jpg', 'line7word7.jpg', 'line7word8.jpg', 'line8word0.jpg', 'line8word1.jpg', 'line8word2.jpg', 'line8word3.jpg', 'line8word4.jpg', 'line8word5.jpg', 'line8word6.jpg', 'line8word7.jpg', 'line8word8.jpg', 'line8word9.jpg', 'line8word10.jpg', 'line9word0.jpg', 'line9word1.jpg', 'line10word0.jpg', 'line10word1.jpg', 'line10word2.jpg', 'line10word3.jpg', 'line11word0.jpg', 'line11word1.jpg', 'line11word2.jpg', 'line11word3.jpg', 'line11word4.jpg', 'line11word5.jpg', 'line11word6.jpg', 'line11word7.jpg', 'line11word8.jpg', 'line11word9.jpg', 'line12word0.jpg', 'line12word1.jpg', 'line12word2.jpg', 'line12word3.jpg']

# %%
main.main()

# %%
# !head -20 data/words.txt
# Out:
# #--- words.txt ---------------------------------------------------------------#
# #
# # iam database word information
# #
# # format: a01-000u-00-00 ok 154 1 408 768 27 51 AT A
# #
# #     a01-000u-00-00  -> word id for line 00 in form a01-000u
# #     ok              -> result of word segmentation
# #                            ok: word was correctly
# #                            er: segmentation of word can be bad
# #
# #     154             -> graylevel to binarize the line containing this word
# #     1               -> number of components for this word
# #     408 768 27 51   -> bounding box around this word in x,y,w,h format
# #     AT              -> the grammatical tag for this word, see the
# #                        file tagset.txt for an explanation
# #     A               -> the transcription for this word
# #
# a01-000u-00-00 ok 154 408 768 27 51 AT A
# a01-000u-00-01 ok 154 507 766 213 48 NN MOVE

# %%
from tensorflow.keras.layers.experimental.preprocessing import StringLookup
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow as tf

import numpy as np
import os

np.random.seed(42)
tf.random.set_seed(42)

# %%
base_path = "data"
words_list = []

words = open(f"{base_path}/words.txt", "r").readlines()
for line in words:
  if line[0] =="#":
    continue
  if line.split(" ")[1] != "err":
    words_list.append(line)

len(words_list)

np.random.shuffle(words_list)

# %%
print(words_list[0:10])
# base_path = "/content/data"
# Out:
# ['e04-030-04-08 ok 170 1489 1499 120 39 JJ sure\n', 'k02-102-05-03 ok 182 836 1623 69 52 PP3A he\n', 'a01-082u-01-04 ok 172 1582 1043 234 88 IN during\n', 'm01-000-07-00 ok 196 339 1998 75 107 INO of\n', 'g01-031-07-06 ok 152 1912 2038 167 59 NN booty\n', 'f07-081b-01-06 ok 168 1366 924 350 88 NN gastronomy\n', 'n03-082-04-03 ok 165 992 1414 118 135 NN boy\n', 'g06-018c-04-05 ok 182 1298 1438 96 58 ATI The\n', 'g06-011j-06-06 ok 182 1222 1785 146 95 CC and\n', 'f04-024-01-06 ok 183 1104 981 60 70 IN in\n']

# %%
# We will split the dataset into three subsets with a 90:5:5 ratio (train:validation:test)

# %%
split_idx = int(0.9*len(words_list))
train_samples = words_list[:split_idx]
test_samples = words_list[split_idx:]

val_split_idx = int(0.5 * len(test_samples))
validation_samples = test_samples[:val_split_idx]
test_samples = test_samples[val_split_idx:]

assert len(words_list) == len(train_samples) + len(validation_samples) + len(test_samples)

print(f"Total Training Samples: {len(train_samples)}")
print(f"Total validation samples: {len(validation_samples)}")
print(f"Total test samples: {len(test_samples)}")
# Out:
# Total Training Samples: 86810
# Total validation samples: 4823
# Total test samples: 4823

# %%
base_image_path = os.path.join(base_path, "words")
print(base_path)
def get_image_paths_and_labels(samples):
  paths = []
  corrected_samples = []
  for (i, file_line) in enumerate(samples):
    line_split = file_line.strip()
    line_split = line_split.split(" ")

    # Each line split willl have this format for the the corresponding image:
    # part1/part1-part2/part1-part2-part3.png
    image_name = line_split[0]
    partI = image_name.split("-")[0]
    partII = image_name.split("-")[1]
    img_path = os.path.join(
        base_image_path, partI, partI + "-" + partII, image_name + ".png"
    )
    if os.path.getsize(img_path):
      paths.append(img_path)
      corrected_samples.append(file_line.split("\n")[0])

  return paths, corrected_samples

train_img_paths, train_labels = get_image_paths_and_labels(train_samples)
validation_img_paths, validation_labels = get_image_paths_and_labels(validation_samples)
test_img_paths, test_labels = get_image_paths_and_labels(test_samples)
# Out:
# /content/data

# %%
base_image_path = os.path.join(base_path, "Outputs2")
print(base_image_path)

t_images = []
from os import listdir
from os.path import isfile, join

# onlyfiles = [f for f in listdir(base_image_path) if isfile(join(base_image_path, f))]
for f in listdir(base_image_path):
  t_images_path = os.path.join(base_image_path, f)
  t_images.append(t_images_path)

print(t_images)
# Out:
# /content/Outputs2
# ['/content/Outputs2/line5word0.jpg', '/content/Outputs2/line9word1.jpg', '/content/Outputs2/line6word9.jpg', '/content/Outputs2/line8word9.jpg', '/content/Outputs2/line3word8.jpg', '/content/Outputs2/line3word6.jpg', '/content/Outputs2/line2word5.jpg', '/content/Outputs2/line5word1.jpg', '/content/Outputs2/line12word1.jpg', '/content/Outputs2/line12word0.jpg', '/content/Outputs2/line4word2.jpg', '/content/Outputs2/line0word0.jpg', '/content/Outputs2/line7word1.jpg', '/content/Outputs2/line0word5.jpg', '/content/Outputs2/line7word3.jpg', '/content/Outputs2/line6word4.jpg', '/content/Outputs2/line8word6.jpg', '/content/Outputs2/line7word2.jpg', '/content/Outputs2/line12word3.jpg', '/content/Outputs2/line0word6.jpg', '/content/Outputs2/line4word0.jpg', '/content/Outputs2/line4word1.jpg', '/content/Outputs2/line3word3.jpg', '/content/Outputs2/line11word0.jpg', '/content/Outputs2/line6word6.jpg', '/content/Outputs2/line2word0.jpg', '/content/Outputs2/line0word3.jpg', '/content/Outputs2/line4word4.jpg', '/content/Outputs2/line0word2.jpg', '/content/Outputs2/line1word2.jpg', '/content/Outputs2/line6word1.jpg', '/content/Outputs2/line0word7.jpg', '/content/Outputs2/line11word9.jpg', '/content/Outputs2/line8word7.jpg', '/content/Outputs2/line7word8.jpg', '/content/Outputs2/line8word10.jpg', '/content/Outputs2/line6word7.jpg', '/content/Outputs2/line1word3.jpg', '/content/Outputs2/line2word1.jpg', '/content/Outputs2/line2word6.jpg', '/content/Outputs2/line7word7.jpg', '/content/Outputs2/line11word2.jpg', '/content/Outputs2/line2word7.jpg', '/content/Outputs2/line3word1.jpg', '/content/Outputs2/line8word5.jpg', '/content/Outputs2/line4word3.jpg', '/content/Outputs2/line10word0.jpg', '/content/Outputs2/line3word9.jpg', '/content/Outputs2/line7word0.jpg', '/content/Outputs2/line3word5.jpg', '/content/Outputs2/line3word2.jpg', '/content/Outputs2/line11word6.jpg', '/content/Outputs2/line7word5.jpg', '/content/Outputs2/line4word5.jpg', '/content/Outputs2/line6word0.jpg', '/content/Outputs2/line8word0.jpg', '/content/Outputs2/line9word0.jpg', '/content/Outputs2/line11word8.jpg', '/content/Outputs2/line11word1.jpg', '/content/Outputs2/line4word7.jpg', '/content/Outputs2/line6word2.jpg', '/content/Outputs2/line7word4.jpg', '/content/Outputs2/line0word8.jpg', '/content/Outputs2/line12word2.jpg', '/content/Outputs2/line8word1.jpg', '/content/Outputs2/line6word3.jpg', '/content/Outputs2/line7word6.jpg', '/content/Outputs2/line2word4.jpg', '/content/Outputs2/line11word7.jpg', '/content/Outputs2/line6word5.jpg', '/content/Outputs2/line8word2.jpg', '/content/Outputs2/line0word1.jpg', '/content/Outputs2/line10word3.jpg', '/content/Outputs2/line11word4.jpg', '/content/Outputs2/line1word0.jpg', '/content/Outputs2/line2word3.jpg', '/content/Outputs2/line11word5.jpg', '/content/Outputs2/line3word0.jpg', '/content/Outputs2/line3word4.jpg', '/content/Outputs2/line4word6.jpg', '/content/Outputs2/line11word3.jpg', '/content/Outputs2/line10word1.jpg', '/content/Outputs2/line3word7.jpg', '/content/Outputs2/line0word4.jpg', '/content/Outputs2/line6word8.jpg', '/content/Outputs2/line10word2.jpg', '/content/Outputs2/line1word1.jpg', '/content/Outputs2/line8word3.jpg', '/content/Outputs2/line2word2.jpg', '/content/Outputs2/line8word4.jpg', '/content/Outputs2/line8word8.jpg']

# %%
t_images[0:10]
# Out:
# ['/content/Outputs2/line5word0.jpg',
#  '/content/Outputs2/line9word1.jpg',
#  '/content/Outputs2/line6word9.jpg',
#  '/content/Outputs2/line8word9.jpg',
#  '/content/Outputs2/line3word8.jpg',
#  '/content/Outputs2/line3word6.jpg',
#  '/content/Outputs2/line2word5.jpg',
#  '/content/Outputs2/line5word1.jpg',
#  '/content/Outputs2/line12word1.jpg',
#  '/content/Outputs2/line12word0.jpg']

# %%
# Sorting string list with numbers

import re

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# alist=[
#     "something1",
#     "something12",
#     "something17",
#     "something2",
#     "something25",
#     "something29"]

t_images.sort(key=natural_keys)
t_images=t_images[1:]
print(t_images)
# Out:
# ['/content/Outputs2/line0word1.jpg', '/content/Outputs2/line0word2.jpg', '/content/Outputs2/line0word3.jpg', '/content/Outputs2/line0word4.jpg', '/content/Outputs2/line0word5.jpg', '/content/Outputs2/line0word6.jpg', '/content/Outputs2/line0word7.jpg', '/content/Outputs2/line0word8.jpg', '/content/Outputs2/line1word0.jpg', '/content/Outputs2/line1word1.jpg', '/content/Outputs2/line1word2.jpg', '/content/Outputs2/line1word3.jpg', '/content/Outputs2/line2word0.jpg', '/content/Outputs2/line2word1.jpg', '/content/Outputs2/line2word2.jpg', '/content/Outputs2/line2word3.jpg', '/content/Outputs2/line2word4.jpg', '/content/Outputs2/line2word5.jpg', '/content/Outputs2/line2word6.jpg', '/content/Outputs2/line2word7.jpg', '/content/Outputs2/line3word0.jpg', '/content/Outputs2/line3word1.jpg', '/content/Outputs2/line3word2.jpg', '/content/Outputs2/line3word3.jpg', '/content/Outputs2/line3word4.jpg', '/content/Outputs2/line3word5.jpg', '/content/Outputs2/line3word6.jpg', '/content/Outputs2/line3word7.jpg', '/content/Outputs2/line3word8.jpg', '/content/Outputs2/line3word9.jpg', '/content/Outputs2/line4word0.jpg', '/content/Outputs2/line4word1.jpg', '/content/Outputs2/line4word2.jpg', '/content/Outputs2/line4word3.jpg', '/content/Outputs2/line4word4.jpg', '/content/Outputs2/line4word5.jpg', '/content/Outputs2/line4word6.jpg', '/content/Outputs2/line4word7.jpg', '/content/Outputs2/line5word0.jpg', '/content/Outputs2/line5word1.jpg', '/content/Outputs2/line6word0.jpg', '/content/Outputs2/line6word1.jpg', '/content/Outputs2/line6word2.jpg', '/content/Outputs2/line6word3.jpg', '/content/Outputs2/line6word4.jpg', '/content/Outputs2/line6word5.jpg', '/content/Outputs2/line6word6.jpg', '/content/Outputs2/line6word7.jpg', '/content/Outputs2/line6word8.jpg', '/content/Outputs2/line6word9.jpg', '/content/Outputs2/line7word0.jpg', '/content/Outputs2/line7word1.jpg', '/content/Outputs2/line7word2.jpg', '/content/Outputs2/line7word3.jpg', '/content/Outputs2/line7word4.jpg', '/content/Outputs2/line7word5.jpg', '/content/Outputs2/line7word6.jpg', '/content/Outputs2/line7word7.jpg', '/content/Outputs2/line7word8.jpg', '/content/Outputs2/line8word0.jpg', '/content/Outputs2/line8word1.jpg', '/content/Outputs2/line8word2.jpg', '/content/Outputs2/line8word3.jpg', '/content/Outputs2/line8word4.jpg', '/content/Outputs2/line8word5.jpg', '/content/Outputs2/line8word6.jpg', '/content/Outputs2/line8word7.jpg', '/content/Outputs2/line8word8.jpg', '/content/Outputs2/line8word9.jpg', '/content/Outputs2/line8word10.jpg', '/content/Outputs2/line9word0.jpg', '/content/Outputs2/line9word1.jpg', '/content/Outputs2/line10word0.jpg', '/content/Outputs2/line10word1.jpg', '/content/Outputs2/line10word2.jpg', '/content/Outputs2/line10word3.jpg', '/content/Outputs2/line11word0.jpg', '/content/Outputs2/line11word1.jpg', '/content/Outputs2/line11word2.jpg', '/content/Outputs2/line11word3.jpg', '/content/Outputs2/line11word4.jpg', '/content/Outputs2/line11word5.jpg', '/content/Outputs2/line11word6.jpg', '/content/Outputs2/line11word7.jpg', '/content/Outputs2/line11word8.jpg', '/content/Outputs2/line11word9.jpg', '/content/Outputs2/line12word0.jpg', '/content/Outputs2/line12word1.jpg', '/content/Outputs2/line12word2.jpg', '/content/Outputs2/line12word3.jpg']

# %%
train_img_paths[0:10]
# Out:
# ['/content/data/words/e04/e04-030/e04-030-04-08.png',
#  '/content/data/words/k02/k02-102/k02-102-05-03.png',
#  '/content/data/words/a01/a01-082u/a01-082u-01-04.png',
#  '/content/data/words/m01/m01-000/m01-000-07-00.png',
#  '/content/data/words/g01/g01-031/g01-031-07-06.png',
#  '/content/data/words/f07/f07-081b/f07-081b-01-06.png',
#  '/content/data/words/n03/n03-082/n03-082-04-03.png',
#  '/content/data/words/g06/g06-018c/g06-018c-04-05.png',
#  '/content/data/words/g06/g06-011j/g06-011j-06-06.png',
#  '/content/data/words/f04/f04-024/f04-024-01-06.png']

# %%
train_labels[0: 10]
# Out:
# ['e04-030-04-08 ok 170 1489 1499 120 39 JJ sure',
#  'k02-102-05-03 ok 182 836 1623 69 52 PP3A he',
#  'a01-082u-01-04 ok 172 1582 1043 234 88 IN during',
#  'm01-000-07-00 ok 196 339 1998 75 107 INO of',
#  'g01-031-07-06 ok 152 1912 2038 167 59 NN booty',
#  'f07-081b-01-06 ok 168 1366 924 350 88 NN gastronomy',
#  'n03-082-04-03 ok 165 992 1414 118 135 NN boy',
#  'g06-018c-04-05 ok 182 1298 1438 96 58 ATI The',
#  'g06-011j-06-06 ok 182 1222 1785 146 95 CC and',
#  'f04-024-01-06 ok 183 1104 981 60 70 IN in']

# %%
# find maximum length and the size of the vocabulary in the training data.

train_labels_cleaned = []
characters = set()
max_len = 0

for label in train_labels:
  label = label.split(" ")[-1].strip()
  for char in label:
    characters.add(char)

  max_len = max(max_len, len(label))
  train_labels_cleaned.append(label)

print("Maximum length: ", max_len)
print("Vocab size: ", len(characters))

# Check some label samples
train_labels_cleaned[:10]
# Out:
# Maximum length:  21
# Vocab size:  78
# ['sure',
#  'he',
#  'during',
#  'of',
#  'booty',
#  'gastronomy',
#  'boy',
#  'The',
#  'and',
#  'in']

# %%
def clean_labels(labels):
  cleaned_labels = []
  for label in labels:
    label = label.split(" ")[-1].strip()
    cleaned_labels.append(label)
  return cleaned_labels

validation_labels_cleaned = clean_labels(validation_labels)
test_labels_cleaned = clean_labels(test_labels)

# %%
ff = list(characters)

# %%
# import pickle
# with open("/content/drive/MyDrive/Colab Notebooks/OCR-new-new/characters", "wb") as fp:
#     pickle.dump(ff, fp)

# %%
import pickle
with open("characters", "rb") as fp:   # Unpickling
    b = pickle.load(fp)
    print(b)
# Out:
# ['L', 'E', '"', '0', '2', 's', 'l', 'w', 'p', 'P', 'H', '/', 'O', 'V', 'f', '!', 'X', 'v', 'M', ':', 'N', '4', '3', "'", 'F', 'J', '(', 'K', '+', 'o', '#', 'I', 'r', '9', ',', '&', '8', 'B', '*', 'Q', 'g', '.', 'W', 'j', 'q', 'm', 'c', '5', ';', '7', 'U', 'h', 'u', 'a', ')', 'R', 'i', 'C', 'z', 'n', '-', 'Y', 'D', 'x', 'd', 'S', 'y', 'Z', 'e', 'k', 'G', '?', 'T', 'A', '6', 't', '1', 'b']

# %%
AUTOTUNE = tf.data.AUTOTUNE

# Maping characaters to integers
char_to_num = StringLookup(vocabulary=b, mask_token=None)

#Maping integers back to original characters
num_to_chars = StringLookup(vocabulary=char_to_num.get_vocabulary(), mask_token=None, invert=True)

# %%
def distortion_free_resize(image, img_size):
  w, h = img_size
  image = tf.image.resize(image, size=(h, w), preserve_aspect_ratio=True)

  # Check tha amount of padding needed to be done.
  pad_height = h - tf.shape(image)[0]
  pad_width = w - tf.shape(image)[1]

  # only necessary if you want to do same amount of padding on both sides.
  if pad_height % 2 != 0:
    height = pad_height // 2
    pad_height_top = height +1
    pad_height_bottom = height
  else:
    pad_height_top = pad_height_bottom = pad_height // 2

  if pad_width % 2 != 0:
    width = pad_width // 2
    pad_width_left = width + 1
    pad_width_right = width
  else:
    pad_width_left = pad_width_right = pad_width // 2

  image = tf.pad(
      image, paddings=[
          [pad_height_top, pad_height_bottom],
          [pad_width_left, pad_width_right],
          [0, 0],
      ],
  )
  image = tf.transpose(image, perm=[1,0,2])
  image = tf.image.flip_left_right(image)
  return image

# %%
batch_size = 64
padding_token = 99
image_width = 128
image_height = 32

def preprocess_image(image_path, img_size=(image_width, image_height)):
  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image, 1)
  image = distortion_free_resize(image, img_size)
  image = tf.cast(image, tf.float32) / 255.0
  return image

def vectorize_label(label):
  label = char_to_num(tf.strings.unicode_split(label, input_encoding="UTF-8"))
  length = tf.shape(label)[0]
  pad_amount = max_len - length
  label = tf.pad(label, paddings=[[0, pad_amount]], constant_values=padding_token)
  return label


def process_images_labels(image_path, label):
  image = preprocess_image(image_path)
  label = vectorize_label(label)
  return {"image": image, "label": label}

def prepare_dataset(image_paths, labels):
  dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels)).map(
    process_images_labels, num_parallel_calls=AUTOTUNE
  )

  return dataset.batch(batch_size).cache().prefetch(AUTOTUNE)

# %%
train_ds = prepare_dataset(train_img_paths, train_labels_cleaned)
validation_ds = prepare_dataset(validation_img_paths, validation_labels_cleaned)
test_ds = prepare_dataset(test_img_paths, test_labels_cleaned)

# %%
# Testing inference images
batch_size = 64
padding_token = 99
image_width = 128
image_height = 32

def preprocess_image(image_path, img_size=(image_width, image_height)):
  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image, 1)
  image = distortion_free_resize(image, img_size)
  image = tf.cast(image, tf.float32) / 255.0
  return image

def process_images_2(image_path):
  image = preprocess_image(image_path)
  # label = vectorize_label(label)
  return {"image": image}

def prepare_test_images(image_paths):
  dataset = tf.data.Dataset.from_tensor_slices((image_paths)).map(
    process_images_2, num_parallel_calls=AUTOTUNE
  )

  # return dataset
  return dataset.batch(batch_size).cache().prefetch(AUTOTUNE)

inf_images = prepare_test_images(t_images)

# %%
# Visualize test images

from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

for data in inf_images.take(1):
  images = data["image"]
  # imm = images.reshape(images.shape[0], (images.shape[1]*images.shape[2]))
  # imm = imm.transpose()
  # print(imm.shape)
  _, ax = plt.subplots(4, 4, figsize=(15, 8))

  # ss = plt.imshow(imm, cmap="gray")
  # plt.show()
  for i in range(16):
    img = images[i]
    # print(img.shape)
    img = tf.image.flip_left_right(img)
    img = tf.transpose(img, perm=[1, 0, 2])
    img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
    img = img[:, :, 0]

    # Gather indices where Label!= padding token

    ax[i // 4, i % 4].imshow(img, cmap="gray")


  plt.show()

# %%
for data in train_ds.take(1):
  images, labels = data["image"], data["label"]
  _, ax = plt.subplots(4, 4, figsize=(15, 8))

  for i in range(16):
    img = images[i]
    # print(img.shape)
    img = tf.image.flip_left_right(img)
    img = tf.transpose(img, perm=[1, 0, 2])
    img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
    img = img[:, :, 0]

    # Gather indices where Label!= padding token
    label = labels[i]
    indices = tf.gather(label, tf.where(tf.math.not_equal(label, padding_token)))
    # Convert to string.
    label = tf.strings.reduce_join(num_to_chars(indices))
    label = label.numpy().decode("utf-8")

    ax[i // 4, i % 4].imshow(img, cmap="gray")
    ax[i // 4, i % 4].set_title(label)
    ax[i // 4, i % 4].axis("off")

  plt.show()

# %%
class CTCLayer(keras.layers.Layer):

  def __init__(self, name=None):
    super().__init__(name=name)
    self.loss_fn = keras.backend.ctc_batch_cost

  def call(self, y_true, y_pred):
    batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
    input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
    label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

    input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")
    loss = self.loss_fn(y_true, y_pred, input_length, label_length)
    self.add_loss(loss)

    # At test time, just return the computed predictions.
    return y_pred

def build_model():
  input_img = keras.Input(shape=(image_width, image_height, 1), name="image")
  labels = keras.layers.Input(name="label", shape=(None,))

  # first conv block
  x = keras.layers.Conv2D(
      32, (3,3), activation = "relu",
      kernel_initializer="he_normal",
      padding="same",
      name="Conv1"
  )(input_img)
  x = keras.layers.MaxPooling2D((2,2), name="pool1")(x)

  # Second conv block
  x = keras.layers.Conv2D(
      64, (3,3), activation = "relu", kernel_initializer="he_normal",
      padding="same",
      name="Conv2"
  )(x)
  x = keras.layers.MaxPooling2D((2,2), name="pool2")(x)

  # We have two maxpool layers with pool size and strides 2
  # Hence downsampled feature maps are 4x smaller the number of filters in the last layer is 64,
  # Reshape accordingly before passing the output to the RNN part of the model.

  new_shape = ((image_width // 4), (image_height // 4) * 64)
  x = keras.layers.Reshape(target_shape=new_shape, name="reshape")(x)
  x = keras.layers.Dense(64, activation="relu", name="dense1")(x)
  x = keras.layers.Dropout(0.2)(x)

  # RNN
  x = keras.layers.Bidirectional(
      keras.layers.LSTM(128, return_sequences=True, dropout=0.25)
  )(x)
  x = keras.layers.Bidirectional(
    keras.layers.LSTM(64, return_sequences=True, dropout=0.25)
  )(x)
  # +2 is to account for the two special tokens introduced by the CTC loss.
  # The recommendation comes here: https://git.10/J0eXP.
  x = keras.layers.Dense(
    len(char_to_num.get_vocabulary()) + 2, activation="softmax", name="dense2"
  )(x)
  # Add CTC layer for calculating CTC Loss at each step.
  output = CTCLayer(name="ctc_loss")(labels, x)

  # Define the model.
  model = keras.models.Model(
      inputs=[input_img, labels], outputs=output, name="handwriting_recognizer"
  )

  # optimizer
  opt = keras.optimizers.Adam()
  # Compile the model and return
  model.compile(optimizer=opt)
  return model

# Get the model
model = build_model()
model.summary()
# Out:
# Model: "handwriting_recognizer"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  image (InputLayer)          [(None, 128, 32, 1)]         0         []
#
#  Conv1 (Conv2D)              (None, 128, 32, 32)          320       ['image[0][0]']
#
#  pool1 (MaxPooling2D)        (None, 64, 16, 32)           0         ['Conv1[0][0]']
#
#  Conv2 (Conv2D)              (None, 64, 16, 64)           18496     ['pool1[0][0]']
#
#  pool2 (MaxPooling2D)        (None, 32, 8, 64)            0         ['Conv2[0][0]']
#
#  reshape (Reshape)           (None, 32, 512)              0         ['pool2[0][0]']
#
#  dense1 (Dense)              (None, 32, 64)               32832     ['reshape[0][0]']
#
#  dropout (Dropout)           (None, 32, 64)               0         ['dense1[0][0]']
#
#  bidirectional (Bidirection  (None, 32, 256)              197632    ['dropout[0][0]']
#  al)
#
#  bidirectional_1 (Bidirecti  (None, 32, 128)              164352    ['bidirectional[0][0]']
#  onal)
#
#  label (InputLayer)          [(None, None)]               0         []
#
#  dense2 (Dense)              (None, 32, 81)               10449     ['bidirectional_1[0][0]']
#
#  ctc_loss (CTCLayer)         (None, 32, 81)               0         ['label[0][0]',
#                                                                      'dense2[0][0]']
#
# ==================================================================================================
# Total params: 424081 (1.62 MB)
# Trainable params: 424081 (1.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Edit Distance is the most widely used metric for evaluating OCR models. In this section, we will implement it and use it as a callback to monitor
# ‘our model.

# We first segregate the validation images and their labels for convenience.

validation_images = []
validation_labels = []

for batch in validation_ds:
  validation_images.append(batch["image"])
  validation_labels.append(batch["label"])

# %%
def calculate_edit_distance(labels, predictions):
  # Get a single batch and convert its labels to sparse tensors.
  sparse_labels = tf.cast(tf.sparse.from_dense(labels), dtype=tf.int64)

  # Make predictions and convert them to sparse tensors.
  input_len = np.ones(predictions.shape[0]) * predictions.shape[1]
  predictions_decoded = keras.backend.ctc_decode(
    predictions, input_length=input_len, greedy=True
  )[0][0][:, :max_len]
  sparse_predictions = tf.cast(
    tf.sparse.from_dense(predictions_decoded), dtype=tf.int64
  )

  # Compute individual edit distances and average them out.
  edit_distances = tf.edit_distance(
    sparse_predictions, sparse_labels, normalize=False
  )
  return tf.reduce_mean(edit_distances)

class EditDistanceCallback(keras.callbacks.Callback):
  def __init__(self, pred_model):
    super().__init__()
    self.prediction_model = pred_model
  def on_epoch_end(self, epoch, logs = None):
    edit_distances = []

    for i in range(len(validation_images)):
      labels = validation_labels[i]
      predictions = self.prediction_model.predict(validation_images[i])
      edit_distances.append(calculate_edit_distance(labels, predictions).numpy())
    print(f"Mean eidt distance for each {epoch + 1}: {np.mean(edit_distances): .4f}")

# %%
  # # Now we are ready to kick off model training,

  # epochs = 50 # To get good results this should be at least 50.

  # model = build_model()
  # prediction_model = keras.models.Model(
  #   model.get_layer(name="image").input, model.get_layer(name="dense2").output
  # )
  # edit_distance_callback = EditDistanceCallback(prediction_model)

  # # Train the model.
  # history = model.fit(
  #   train_ds,
  #   validation_data=validation_ds,
  #   epochs=epochs,
  #   callbacks=[edit_distance_callback],
  # )

# %%
# #Saving thje model

# model.save_weights('/content/drive/MyDrive/Colab Notebooks/OCR-new-new/ocr_model_v4.h5')
# prediction_model.save_weights('/content/drive/MyDrive/Colab Notebooks/OCR-new-new/ocr_model_v5.h5')

# # # # #Below is working saved models
# model.save("/content/drive/MyDrive/Colab Notebooks/OCR-new-new/ocr_model_v8.h5")
# prediction_model.save("/content/drive/MyDrive/Colab Notebooks/OCR-new-new/ocr_model_50_epoch.h5")
# # from tensorflow.keras.models import load_model
# # prediction_model=tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/OCR-new-new/ocr_model_50_epoch.h5')

# %%
# from tensorflow import keras

# # Custom objects need to be defined when loading a model with custom layers.
# custom_objects = {"CTCLayer": CTCLayer}

# # Load the model from the SavedModel directory.
# reconstructed_model = keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/OCR-new-new/ocr_model_50_epoch.h5", custom_objects=custom_objects)

# # Alternatively, load the model from an HDF5 file.
# #reconstructed_model = keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/OCR/ocr_model_50_epoch.h5", custom_objects=custom_objects)

# # Create the prediction model.
# prediction_model = keras.models.Model(
#     reconstructed_model.get_layer(name="image").input,
#     reconstructed_model.get_layer(name="dense2").output
# )

# # Utility function to decode the output of the network.
# def decode_batch_predictions(pred):
#     input_len = np.ones(pred.shape[0]) * pred.shape[1]
#     results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][:, :max_len]
#     output_text = []

#     for res in results:
#         res = tf.gather(res, tf.where(tf.math.not_equal(res, -1)))
#         res = tf.strings.reduce_join(num_to_chars(res)).numpy().decode("utf-8")
#         output_text.append(res)

#     return output_text
# # Prepare inference dataset (example with test set, can be replaced with new images dataset)
# inf_images = prepare_dataset(test_img_paths, test_labels_cleaned)

# # Inference on new images.
# for batch in inf_images.take(1):
#     batch_images = batch["image"]
#     preds = prediction_model.predict(batch_images)
#     pred_texts = decode_batch_predictions(preds)

#     for i in range(len(batch_images)):
#         img = batch_images[i]
#         img = tf.image.flip_left_right(img)
#         img = tf.transpose(img, perm=[1, 0, 2])
#         img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
#         img = img[:, :, 0]

#         title = f"Prediction: {pred_texts[i]}"
#         plt.imshow(img, cmap="gray")
#         plt.title(title)
#         plt.axis("off")
#         plt.show()

# %%
# # from google.colab import drive
# from tensorflow.keras.models import load_model

# # # Mount Google Drive
# # drive.mount('/content/drive')

# # Define CTCLayer
# import tensorflow as tf
# from tensorflow.keras.layers import Layer

# class CTCLayer(Layer):
#     def __init__(self, **kwargs):
#         super(CTCLayer, self).__init__(**kwargs)

#     def call(self, y_true, y_pred):
#         # Define the custom computation logic here
#         return y_pred

#     def get_config(self):
#         config = super(CTCLayer, self).get_config()
#         return config

# # Load the full model
# model_path = '/content/drive/MyDrive/Colab Notebooks/OCR-new-new/ocr_model_v8.h5'
# model = load_model(model_path, custom_objects={'CTCLayer': CTCLayer})

# Load the prediction model
# prediction_model_path = '/content/drive/MyDrive/Colab Notebooks/OCR-new-new/ocr_model_50_epoch.h5'
# prediction_model = load_model(prediction_model_path, custom_objects={'CTCLayer': CTCLayer})

# %%
# # A utility function to decode the output of the network
# def decode_batch_predictions(pred):
#     input_len = np.ones(pred.shape[0]) * pred.shape[1]
#     # Use greedy search. For complex tasks, you can use beam search.
#     results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
#         :, :max_len
#     ]

#     # Iterate over the results and get back the text.
#     output_text = []

#     for res in results:
#       res = tf.gather(res, tf.where(tf.math.not_equal(res, -1)))
#       res = tf.strings.reduce_join(num_to_chars(res)).numpy().decode("utf-8")
#       output_text.append(res)

#     return output_text


# # Let's check results on sone test samples.
# for batch in test_ds.take(1):
#     batch_images = batch["image"]
#     print(batch_images.shape)

#     _, ax = plt.subplots(4, 4, figsize=(15, 8))

#     preds = prediction_model.predict(batch_images)
#     pred_texts = decode_batch_predictions(preds)

#     for i in range(16):
#       img = batch_images[i]
#       img = tf.image.flip_left_right(img)
#       img = tf.transpose(img, perm=[1, 0, 2])
#       img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
#       img = img[:, :, 0]

#       title = f"Prediction: {pred_texts[i]}"
#       ax[i // 4, i % 4].imshow(img, cmap = "gray")
#       ax[i // 4, i % 4].set_title(title)
#       ax[i // 4, i % 4].axis("off")

#     plt.show()

# %%
custom_objects = {"CTCLayer": CTCLayer}

# %%
reconstructed_model = keras.models.load_model("/content/drive/MyDrive/Colab Notebooks/OCR-new-new/ocr_model_50_epoch.h5", custom_objects=custom_objects)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# # A utility function to decode the output of the network
# def decode_batch_predictions(pred):
#     input_len = np.ones(pred.shape[0]) * pred.shape[1]
#     # Use greedy search. For complex tasks, you can use beam search.
#     results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
#         :, :max_len
#     ]

#     # Iterate over the results and get back the text.
#     output_text = []

#     for res in results:
#       res = tf.gather(res, tf.where(tf.math.not_equal(res, -1)))
#       res = tf.strings.reduce_join(num_to_chars(res)).numpy().decode("utf-8")
#       output_text.append(res)

#     return output_text


# # Let's check results on sone test samples.
# for batch in test_ds.take(1):
#     batch_images = batch["image"]
#     print(batch_images.shape)

#     _, ax = plt.subplots(4, 4, figsize=(15, 8))

#     preds = reconstructed_model_model.predict(batch_images)
#     pred_texts = decode_batch_predictions(preds)

#     for i in range(16):
#       img = batch_images[i]
#       img = tf.image.flip_left_right(img)
#       img = tf.transpose(img, perm=[1, 0, 2])
#       img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
#       img = img[:, :, 0]

#       title = f"Prediction: {pred_texts[i]}"
#       ax[i // 4, i % 4].imshow(img, cmap = "gray")
#       ax[i // 4, i % 4].set_title(title)
#       ax[i // 4, i % 4].axis("off")

#     plt.show()

# %%
prediction_model = keras.models.Model(
  reconstructed_model.get_layer(name="image").input, reconstructed_model.get_layer(name="dense2").output
)

# %%
# Inference on New set of images
pred_test_text = []

# A utility function to decode the output of the network
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
    # Use greedy search. For complex tasks, you can use beam search.
    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
        :, :max_len
    ]

    # Iterate over the results and get back the text.
    output_text = []

    for res in results:
      res = tf.gather(res, tf.where(tf.math.not_equal(res, -1)))
      res = tf.strings.reduce_join(num_to_chars(res)).numpy().decode("utf-8")
      output_text.append(res)

    return output_text


# Let's check results on sone test samples.
for batch in inf_images.take(3):
    batch_images = batch["image"]
    # batch_images= tf.expand_dims(batch_images, axis=0)
    print(batch_images.shape)
    # print(batch_images.shape)

    _, ax = plt.subplots(4, 4, figsize=(15, 8))

    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)
    pred_test_text.append(pred_texts)

    for i in range(16):
      img = batch_images[i]
      img = tf.image.flip_left_right(img)
      img = tf.transpose(img, perm=[1, 0, 2])
      img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
      img = img[:, :, 0]

      title = f"Prediction: {pred_texts[i]}"
      ax[i // 4, i % 4].imshow(img, cmap = "gray")
      ax[i // 4, i % 4].set_title(title)
      ax[i // 4, i % 4].axis("off")

    plt.show()
# Out:
# (64, 128, 32, 1)
# 2/2 [==============================] - 2s 91ms/step
# (26, 128, 32, 1)
# 1/1 [==============================] - 2s 2s/step

# %%
for batch in inf_images:
    batch_images = batch["image"]
    # batch_images= tf.expand_dims(batch_images, axis=0)
    print(batch_images.shape)
# Out:
# (64, 128, 32, 1)
# (26, 128, 32, 1)

# %%
flat_list = [item for sublist in pred_test_text for item in sublist]
print(flat_list)
# Out:
# ['Thank', 'ro.', '.', 'CMaCNB0', 'nonpar', 'It', 'plusde', 'reme', 'en', 'francais', 'umnaunmonment', 'anor', 'Ie', 'Lorerm', '1psumest', 'is', 'faux', 'lexe', 'standardde', 'limpri-', 'mene', 'depuis', 'les', 'anaees', '.', '1500.', 'auand', 'ua', 'unprimeut', 'ano-', 'ayae', 'ussenthewsenble', 'des', 'morceaue', "'e", 'rexe', 'pour', 'sea-', 'liser', 'atmrepenmtestandens', 'lorem', 'snoum', 'is', 'simply', 'ummn', 'sexr', 'of', 'the', 'nrmams', 'and', 'wneserts', 'industrn', 'lorem', 'Inoum', 'has', 'been', 'the', 'industrn', "'s", 'standard', 'dumms', 'ser', 'ever', 'smce', 'the', '.', '1500s.', 'when', 'an', 'um.', 'hromomoratmetent', 'wpeneoramtalvanak', 'a', '1ipe', 'specmen', 'book', '"', 'has', 'survived', 'nor', 'ens', 'tive', 'cenmunesi', 'but', 'alsothe', 'lean', 'intoelectranic', 'Nnesettmss', 'renaninpesentath', 'unchansed']

# %%
sentence = ' '.join(flat_list)
print(sentence)
# Out:
# Thank ro. . CMaCNB0 nonpar It plusde reme en francais umnaunmonment anor Ie Lorerm 1psumest is faux lexe standardde limpri- mene depuis les anaees . 1500. auand ua unprimeut ano- ayae ussenthewsenble des morceaue 'e rexe pour sea- liser atmrepenmtestandens lorem snoum is simply ummn sexr of the nrmams and wneserts industrn lorem Inoum has been the industrn 's standard dumms ser ever smce the . 1500s. when an um. hromomoratmetent wpeneoramtalvanak a 1ipe specmen book " has survived nor ens tive cenmunesi but alsothe lean intoelectranic Nnesettmss renaninpesentath unchansed
